# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/7f/85/b9c2fc5758abb2084e75a74ff4ee0152c2df661826eba3bc652a4cb559e4/xgboost-1.3.3-py3-none-macosx_10_14_x86_64.macosx_10_15_x86_64.macosx_11_0_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 3.2MB/s eta 0:00:01
# Requirement already satisfied: scipy in /Users/davidrollins/opt/anaconda3/lib/python3.7/site-packages (from xgboost) (1.3.1)
# Requirement already satisfied: numpy in /Users/davidrollins/opt/anaconda3/lib/python3.7/site-packages (from xgboost) (1.17.2)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.3.3

# %%
# !brew install libomp
# Out:
# Updating Homebrew...
# ==> Downloading https://homebrew.bintray.com/bottles-portable-ruby/portable-ruby-2.6.3_2.yosemite.bottle.tar.gz
# #######################################################################   99.4%####                                                                     8.9%####################################### 100.0%
# ==> Pouring portable-ruby-2.6.3_2.yosemite.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# acl2                       gradle-profiler            openfast
# act                        graphql-cli                openfst
# aerc                       gravity                    openjdk@8
# aida-header                grokj2k                    openmama
# airshare                   grokmirror                 openmodelica
# aliddns                    grpcui                     openstackclient
# alsa-lib                   gtkmm4                     oq
# amp                        guile@2                    or-tools
# ansible@2.9                gulp-cli                   oras
# apidoc                     h2spec                     ormolu
# arb                        halide                     ory-hydra
# argo                       hashlink                   osi
# argocd                     haskell-language-server    osm
# arrayfire                  hasura-cli                 osmcoastline
# arturo                     hblock                     overdrive
# as-tree                    hcxtools                   ox
# asimov                     hdf5-mpi                   packetbeat
# asroute                    hdt                        packr
# asuka                      heksa                      pandoc-include-code
# athenacli                  heppdt2                    pandocomatic
# atkmm@2.28                 hexo                       parallel-hashmap
# attr                       hsd                        parliament
# austin                     htmltest                   pass-git-helper
# autodiff                   httpx                      pcalc
# aws-console                hy                         pdftilecut
# aws-rotate-key             i686-elf-binutils          pdm
# awsweeper                  i686-elf-gcc               periscope
# azcopy                     iconsur                    pfetch
# bandit                     idris2                     phive
# bas55                      immudb                     php@7.4
# bcoin                      indicators                 pickle
# beancount                  infracost                  pipgrip
# bit-git                    inframap                   pkger
# blaze                      inja                       po4a
# blogc                      inko                       podman
# bnfc                       inxi                       postgresql@12
# bombadillo                 ioctl                      projectm
# bond                       isl@0.18                   prometheus-cpp
# bootloadhid                isort                      promtail
# borgbackup                 jc                         protoc-gen-go-grpc
# box2d                      jerryscript                protoc-gen-gogo
# bpython                    jimtcl                     protoc-gen-gogofaster
# bpytop                     jinx                       ptpython
# buildozer                  jobber                     publish
# c7n                        jolie                      pwncat
# cadence                    jpeg-xl                    pyqt-3d
# cairomm@1.14               jql                        pyqt-builder
# cargo-audit                json5                      pyqt-networkauth
# cargo-edit                 jsonnet-bundler            pyqt@5
# cargo-watch                k3sup                      pyside@2
# carton                     k9s                        python-tabulate
# cassowary                  kamel                      python@3.7
# castget                    kcgi                       python@3.9
# cbc                        kde-extra-cmake-modules    qrcp
# cbmc                       kde-karchive               qt-libiodbc
# ccheck                     kde-kdoctools              qt-mariadb
# cddlib                     kde-ki18n                  qt-mysql
# cdk8s                      kde-threadweaver           qt-percona-server
# cdktf                      keptn                      qt-postgresql
# cdo                        kertish-dfs                qt-unixodbc
# cfn-flip                   khiva                      quill
# cfn-format                 klee                       rain
# cgl                        ko                         rbtools
# chalk-cli                  kona                       rcm
# charge                     kondo                      rdkit
# chars                      kotlin-language-server     redo
# chart-testing              ksync                      reg
# checkov                    kube-linter                regipy
# cherrytree                 kubecm                     reorder-python-imports
# chezmoi                    kubergrunt                 rgf
# choose-rust                kubevela                   richmd
# chrony                     kubie                      rm-improved
# clair                      kumactl                    rqlite
# clang-format@8             lab                        rtl_433
# clash                      ladspa-sdk                 rtorrent
# claws-mail                 lanraragi                  rttr
# cli11                      latexindent                ruby@2.7
# clip                       latino                     rust-analyzer
# cloud-nuke                 lc0                        rustscan
# cloudflare-wrangler        ldpl                       s2n
# cloudformation-cli         leaf                       saltwater
# cloudformation-guard       leakcanary-shark           saml2aws
# coconut                    libaio                     sdns
# code-server                libbsd                     semgrep
# coin3d                     libcap                     semtag
# colfer                     libcap-ng                  server-go
# commitizen                 libcouchbase@2             shallow-backup
# condure                    libcpuid                   sheldon
# confd                      libdmx                     showkey
# container-structure-test   libdrm                     shtools
# copilot                    libfontenc                 silicon
# coredns                    libfs                      simdjson
# cortex                     libfuse                    skylighting
# counterfeiter              libgccjit                  sleef
# cpio                       libgnt                     smlpkg
# cpm                        libhandy                   snap
# cpplint                    libice                     snowpack
# cpr                        libirecovery               so
# cqlkit                     libmd                      solidity
# crane                      libmnl                     sollya
# crcany                     libnetfilter-queue         sonic
# crispy-doom                libnetworkit               spack
# croaring                   libnfnetlink               sponge
# croc                       libnsl                     spotify-tui
# cubejs-cli                 libolm                     spotifyd
# cucumber-ruby              liboqs                     sqlancer
# curlie                     libpciaccess               sqlc
# cvs-fast-export            libpinyin                  sqlite-utils
# dasel                      libpipeline                standardese
# datalad                    libpqxx@6                  staticcheck
# datasette                  libprelude                 strace
# dbdeployer                 libpthread-stubs           structurizr-cli
# delve                      librttopo                  subfinder
# detach                     libseccomp                 swift-format
# device-mapper              libslirp                   t-rec
# dgraph                     libsm                      tanka
# dhall-yaml                 libtirpc                   taskwarrior-tui
# diskonaut                  libtorrent-rakshasa        tctl
# dmagnetic                  libunwind                  tendermint
# dnsprobe                   libva                      tengo
# dnsx                       libvdpau                   termcolor
# doctest                    libvnc                     terracognita
# docui                      libx11                     terraform-ls
# dog                        libxau                     terraform@0.12
# dolt                       libxaw                     terraform@0.13
# dosbox-staging             libxaw3d                   terrascan
# dotenv-linter              libxcb                     tfsec
# dotnet                     libxcomposite              tgenv
# dprint                     libxcursor                 thanos
# driftctl                   libxdamage                 thrax
# dstask                     libxdmcp                   threemux
# duckdb                     libxext                    tlx
# duckscript                 libxfixes                  tm
# duf                        libxfont                   tomcat@9
# duktape                    libxft                     toot
# earthly                    libxi                      torchvision
# easy-rsa                   libxinerama                trailscraper
# efm-langserver             libxkbfile                 tre-command
# eksctl                     libxml++@4                 trec_eval
# eleventy                   libxml++@5                 tree-sitter
# emacs-dracula              libxmu                     trimage
# empty                      libxp                      truffle
# envoy                      libxpm                     trunk
# enzyme                     libxrandr                  ugrep
# erlang@22                  libxrender                 unum
# eva                        libxres                    uptoc
# evernote2md                libxscrnsaver              usb.ids
# f3d                        libxshmfence               utf8cpp
# fargatecli                 libxt                      util-macros
# fava                       libxtst                    uutils-coreutils
# fblog                      libxv                      v2ray
# fcct                       libxvmc                    vapor
# fennel                     libxxf86dga                vc
# fetch                      libxxf86vm                 vcpkg
# field3d                    linux-headers              vgrep
# fizz                       litecli                    vint
# flamegraph                 lizard-analyzer            vitess
# flank                      llvm@9                     vivid
# flarectl                   localstack                 vlang
# flash                      logcli                     vlmcsd
# fleet-cli                  logswan                    volk
# flit                       loki                       volta
# flow-cli                   lp_solve                   vpn-slice
# flux                       lttng-ust                  vroom
# fnm                        lua@5.3                    vsearch
# folderify                  luajit-openresty           vsh
# font-util                  lunchy                     vtk@8.2
# foreman                    lunchy-go                  vulture
# forge                      luv                        waffle
# fpart                      macos-trash                wangle
# fpdns                      magic_enum                 wasm-pack
# fplll                      mandown                    wayland
# functionalplus             mariadb@10.4               wayland-protocols
# gallery-dl                 markdownlint-cli           webify
# gateway-go                 marked                     wgcf
# gau                        mask                       wllvm
# gcalcli                    massdns                    wolfmqtt
# gcc@9                      matplotplusplus            wownero
# gdbgui                     md4c                       wren
# gdu                        mermaid-cli                wren-cli
# geph2                      mesa-glu                   x86_64-elf-gdb
# geph4                      mhonarc                    xbitmaps
# ghc@8.8                    microplane                 xcb-proto
# ghc@9                      minipro                    xcb-util
# ghz                        mockery                    xcb-util-cursor
# ghz-web                    mockolo                    xcb-util-image
# git-bug                    mpdecimal                  xcb-util-keysyms
# git-hooks-go               msc-generator              xcb-util-renderutil
# git-hound                  mtoc                       xcb-util-wm
# git-remote-codecommit      muffet                     xcbeautify
# gitlint                    naabu                      xcinfo
# gitql                      name-that-hash             xclogparser
# gitui                      nanorc                     xcprojectlint
# giza                       ncspot                     xdpyinfo
# glab                       nef                        xinput
# glibc                      nest                       xkeyboardconfig
# gluon                      networkit                  xorgproto
# gmailctl                   never                      xorgrgb
# go-jsonnet                 nfpm                       xray
# go@1.14                    ngs                        xterm
# go@1.15                    nicotine-plus              xtrans
# gobo                       node@14                    xxh
# gocloc                     notmuch-mutt               yh
# gofish                     nuclei                     yj
# gofumpt                    numactl                    ykdl
# gojq                       numcpp                     youtube-dlc
# golangci-lint              oakc                       youtubedr
# googletest                 ocaml-zarith               yq@3
# gopass-jsonapi             oci-cli                    yubikey-agent
# gopls                      odin                       z.lua
# goredo                     oha                        zenith
# gosec                      oil                        zlib-ng
# gost                       omake                      zoxide
# gostatic                   open-adventure             zsh-async
# gping                      openalpr                   zsh-you-should-use
# ==> Updated Formulae
# Updated 4818 formulae.
# ==> Renamed Formulae
# elasticsearch@6.8 -> elasticsearch@6
# glibmm@2.64 -> glibmm@2.66
# gst-validate -> gst-devtools
# gtk+4 -> gtk4
# ht-rust -> xh
# interactive-rebase-tool -> git-interactive-rebase-tool
# jfrog-cli-go -> jfrog-cli
# kibana@6.8 -> kibana@6
# libsasl2 -> cyrus-sasl
# mkl-dnn -> onednn
# now-cli -> vercel-cli
# pangomm@2.42 -> pangomm@2.46
# prest -> prestd
# qt5 -> qt@5
# ==> Deleted Formulae
# python ✔                   elasticsearch@5.6          pijul
# apache-zeppelin            fmsx                       residualvm
# avian                      geant4                     rmtrash
# baidupcs-go                gnome-builder              sflowtool
# biogeme                    gobby                      stlviewer
# boost@1.55                 godep                      syncthing-inotify
# boost@1.59                 highlighting-kate          tomee-jax-rs
# cargo-completion           i386-elf-grub              unp64
# compcert                   kibana@5.6                 unrar
# confluent-platform         llvm@6                     unravel
# crc                        lumo                       urbit
# cryptopp                   marathon-swift             woboq_codebrowser
# curl-openssl               meson-internal             wpscan
# deis                       mysql-connector-c++@1.1    xspin
# deisctl                    open-cobol                 xu4
# dtrx                       ori
# elasticsearch@2.4          pgplot
# ==> Downloading https://homebrew.bintray.com/bottles/libomp-11.1.0.mojave.bottle
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/aa823f2fef52a032496f4
# ######################################################################## 100.0%
# ==> Pouring libomp-11.1.0.mojave.bottle.tar.gz
# 🍺  /usr/local/Cellar/libomp/11.1.0: 9 files, 1.4MB
# ==> `brew cleanup` has not been run in 30 days, running now...
# Removing: /Users/davidrollins/Library/Caches/Homebrew/arm-none-eabi-gcc--9-2019-q4-major.tar.bz2... (111.4MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/gettext--0.20.1.mojave.bottle.tar.gz... (8.4MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/glib--2.64.0.mojave.bottle.tar.gz... (4.6MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/gmp--6.2.0.mojave.bottle.tar.gz... (1022.7KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/gnutls--3.6.12.mojave.bottle.tar.gz... (3MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/hidapi--0.9.0.mojave.bottle.tar.gz... (35KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/jpeg--9d.mojave.bottle.tar.gz... (308.5KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/libevent--2.1.11_1.mojave.bottle.tar.gz... (1.2MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/libffi--3.2.1.mojave.bottle.tar.gz... (91.8KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/libftdi--1.4_2.mojave.bottle.tar.gz... (109.1KB)
# Removing: /usr/local/Cellar/libidn2/2.2.0... (70 files, 700.9KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/libidn2--2.3.0.mojave.bottle.tar.gz... (233.3KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/libpng--1.6.37.mojave.bottle.tar.gz... (442.2KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/libssh--0.9.3.mojave.bottle.tar.gz... (219.3KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/libtasn1--4.16.0.mojave.bottle.tar.gz... (121.9KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/libusb--1.0.23.mojave.bottle.tar.gz... (168.4KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/libusb-compat--0.1.5_1.mojave.bottle.tar.gz... (31.9KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/lzo--2.10.mojave.bottle.tar.gz... (150.0KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/ncurses--6.2.mojave.bottle.tar.gz... (2.3MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/nettle--3.4.1.mojave.bottle.tar.gz... (730.8KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/open-ocd--0.10.0.mojave.bottle.2.tar.gz... (1.6MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/openssl@1.1--1.1.1d.mojave.bottle.tar.gz... (5.2MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/p11-kit--0.23.20.mojave.bottle.tar.gz... (703.0KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/pcre--8.44.mojave.bottle.tar.gz... (1.8MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/pixman--0.38.4.mojave.bottle.tar.gz... (502.2KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/qemu--4.2.0.mojave.bottle.tar.gz... (93.9MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/readline--8.0.4.mojave.bottle.tar.gz... (517.6KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/sqlite--3.31.1.mojave.bottle.tar.gz... (1.9MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/unbound--1.10.0.mojave.bottle.tar.gz... (2.5MB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/vde--2.3.2.mojave.bottle.tar.gz... (222.9KB)
# Removing: /Users/davidrollins/Library/Caches/Homebrew/python--3.7.7.mojave.bottle.tar.gz... (14.9MB)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/gmp... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/libidn2... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/libpng... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/ncurses... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/nettle... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/pixman... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/python... (3 files, 148.3KB)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/libftdi... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/glib... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/readline... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/sqlite... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/vde... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/libusb-compat... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/gettext... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/arm-none-eabi-gcc... (130B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/qemu... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/hidapi... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/open-ocd... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/libtasn1... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/libssh... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/libevent... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/pcre... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/unbound... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/jpeg... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/libusb... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/p11-kit... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/lzo... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/libffi... (64B)
# Removing: /Users/davidrollins/Library/Logs/Homebrew/gnutls... (64B)
# Pruned 2 symbolic links and 7 directories from /usr/local

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
import xgboost as xgb
import time

# %% [markdown]
# Use Random Forests to try to get the best possibletest accuracyon MNIST. This involves getting  acquainted  with  how  Random  Forests  work,  understanding  their  parameters,  andtherefore using Cross Validation to find the best settings.  How well can you do?  You shoulduse the accuracy metric, since this is what you used in Lab 5 – therefore this will allow you tocompare your results from Random Forests with your results from L1- and L2- RegularizedLogistic Regression.  What are the hyperparameters of your best model?

# %%
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
forest = RandomForestClassifier(max_features='log2', max_depth=20)
                                
param_grid = {
'n_estimators':[x for x in range(10, 80, 10)],
'criterion':['gini', 'entropy']
}

forest_CV = GridSearchCV(estimator=forest, param_grid=param_grid, cv=10)
forest_CV.fit(X_train, y_train)
print("best parameters: " + str(forest_CV.best_params_))


prediction = []
for i in range(X_test.shape[0]):
    prediction.append(forest_CV.predict([X_test[i, :]]))

print("Score: " + str(accuracy_score(y_test, prediction)))
# Out:
# best parameters: {'criterion': 'entropy', 'n_estimators': 70}
# Score: 0.9657857142857142

# %% [markdown]
# Use  Boosting  to  do  the  same.   Take  the  time  to  understand  how  XGBoost  works  (and/orother boosting packages available).  Try your best to tune your hyper-parameters.  As addedmotivation:  typically the winners and near-winners of the Kaggle competition are those that are best able to tune an cross validate XGBoost.  What are the hyperparameters of your bestmodel?

# %%
import warnings

warnings.filterwarnings("ignore")

boosted_forest = xgb.XGBClassifier(n_jobs=-1)

param_grid_Boost = {
    'n_estimators':[x for x in range(10,40,10)],
    'max_depth':[x for x in range(1,5)],
    'learning_rate':[.05],
    'subsample':[.2]
}

forest_GS = GridSearchCV(estimator=boosted_forest, param_grid=param_grid_Boost, cv=5)
forest_GS.fit(X_train, y_train, eval_metric='auc')
print(forest_GS.best_params_)

print(accuracy_score(y_test, forest_GS.predict(X_test)))
# Out:
# {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 30, 'subsample': 0.2}
# 0.8956428571428572
